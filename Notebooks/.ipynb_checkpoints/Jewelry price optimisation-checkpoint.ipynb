# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import datetime as dt

sns.set()

# %%
#import dataset
df = pd.read_csv("../Data/Jewelry_Dataset.csv")

# %% [markdown]
# ## Data cleaning and EDA

# %%
#peeking dataset
df.head(5)
# Out:
#    2018-12-01 11:40:29 UTC  1924719191579951782  1842195256808833386  1  \
# 0  2018-12-01 17:38:31 UTC  1924899396621697920  1806829193678291446  1
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556  1
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453  1
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865  1
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449  1
#
#    1806829201890738522   jewelry.earring    0  561.51  1515915625207851155  \
# 0         1.806829e+18               NaN  NaN  212.14         1.515916e+18
# 1         1.806829e+18   jewelry.pendant  1.0   54.66         1.515916e+18
# 2         1.806829e+18   jewelry.pendant  0.0   88.90         1.515916e+18
# 3         1.806829e+18  jewelry.necklace  0.0  417.67         1.515916e+18
# 4         1.806829e+18   jewelry.earring  1.0  102.27         1.515916e+18
#
#   Unnamed: 9     red  gold   diamond
# 0        NaN  yellow  gold       NaN
# ...

# %%
df.columns=[
"Order_date",
"Order_ID",
"product_ID",
"SKU_quantity",
"category_ID",
"category_alias",
"brand_ID",
"Price_USD",
"user_ID",
"gender",
"main_color",
"main_metal",
"main_gem"]

# %%
df.head(10)
# Out:
#                 Order_date             Order_ID           product_ID  \
# 0  2018-12-01 17:38:31 UTC  1924899396621697920  1806829193678291446
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449
# 5  2018-12-02 22:09:34 UTC  1925760595336888995  1600021442638905547
# 6  2018-12-02 22:16:20 UTC  1925764002260976330  1835566854106513435
# 7  2018-12-03 07:03:49 UTC  1926029494397698277  1811798112444875309
# 8  2018-12-03 09:48:34 UTC  1926112416450478161  1836278824443052965
# 9  2018-12-03 09:48:34 UTC  1926112416450478161  1877637299521454325
#
#    SKU_quantity   category_ID    category_alias  brand_ID  Price_USD  \
# 0             1  1.806829e+18               NaN       NaN     212.14
# ...

# %%
#check data info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95910 entries, 0 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_date      95910 non-null  object
#  1   Order_ID        95910 non-null  int64
#  2   product_ID      95910 non-null  int64
#  3   SKU_quantity    95910 non-null  int64
#  4   category_ID     90558 non-null  float64
#  5   category_alias  85977 non-null  object
#  6   brand_ID        91125 non-null  float64
#  7   Price_USD       90558 non-null  float64
#  8   user_ID         90558 non-null  float64
#  9   gender          47743 non-null  object
#  10  main_color      88250 non-null  object
#  11  main_metal      90448 non-null  object
#  12  main_gem        61852 non-null  object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 9.5+ MB

# %%
#check for data description
df.describe(include="all")
# Out:
#                      Order_date      Order_ID    product_ID  SKU_quantity  \
# count                     95910  9.591000e+04  9.591000e+04       95910.0
# unique                    74504           NaN           NaN           NaN
# top     2020-10-17 12:58:28 UTC           NaN           NaN           NaN
# freq                         26           NaN           NaN           NaN
# mean                        NaN  2.485191e+18  1.815970e+18           1.0
# std                         NaN  1.934750e+17  2.136814e+17           0.0
# min                         NaN  1.924899e+18  1.313551e+18           1.0
# 25%                         NaN  2.379732e+18  1.515966e+18           1.0
# 50%                         NaN  2.524282e+18  1.956664e+18           1.0
# 75%                         NaN  2.644347e+18  1.956664e+18           1.0
# max                         NaN  2.719022e+18  2.541962e+18           1.0
#
#          category_ID   category_alias      brand_ID     Price_USD  \
# ...

# %%
#convert order date column to datetime
df["Order_date"] = pd.to_datetime(df["Order_date"], errors='coerce')

# %%
df.head(10)
# Out:
#                  Order_date             Order_ID           product_ID  \
# 0 2018-12-01 17:38:31+00:00  1924899396621697920  1806829193678291446
# 1 2018-12-02 13:53:42+00:00  1925511016616034733  1842214461889315556
# 2 2018-12-02 17:44:02+00:00  1925626951238681511  1835566849434059453
# 3 2018-12-02 21:30:19+00:00  1925740842841014667  1873936840742928865
# 4 2018-12-02 22:09:34+00:00  1925760595336888995  1835566854827934449
# 5 2018-12-02 22:09:34+00:00  1925760595336888995  1600021442638905547
# 6 2018-12-02 22:16:20+00:00  1925764002260976330  1835566854106513435
# 7 2018-12-03 07:03:49+00:00  1926029494397698277  1811798112444875309
# 8 2018-12-03 09:48:34+00:00  1926112416450478161  1836278824443052965
# 9 2018-12-03 09:48:34+00:00  1926112416450478161  1877637299521454325
#
#    SKU_quantity   category_ID    category_alias  brand_ID  Price_USD  \
# 0             1  1.806829e+18               NaN       NaN     212.14
# ...

# %%
#check for duplicate values
duplicates = len(df.loc[df.duplicated()])

# %%
print(f"Number of duplicated values is",duplicates)
# Out:
# Number of duplicated values is 2589

# %%
#check for missing values
df.isnull().sum()
# Out:
# Order_date            0
# Order_ID              0
# product_ID            0
# SKU_quantity          0
# category_ID        5352
# category_alias     9933
# brand_ID           4785
# Price_USD          5352
# user_ID            5352
# gender            48167
# main_color         7660
# main_metal         5462
# main_gem          34058
# dtype: int64

# %%
# drop columns not relevant for this course
dropped_columns = ["Order_ID","product_ID","user_ID","Order_date"]

data_with_drop_column = df.drop(columns = dropped_columns)

# %%
#peek new data
data_with_drop_column.head(10)
# Out:
#    SKU_quantity   category_ID    category_alias  brand_ID  Price_USD gender  \
# 0             1  1.806829e+18               NaN       NaN     212.14    NaN
# 1             1  1.806829e+18   jewelry.pendant       1.0      54.66      f
# 2             1  1.806829e+18   jewelry.pendant       0.0      88.90      f
# 3             1  1.806829e+18  jewelry.necklace       0.0     417.67    NaN
# 4             1  1.806829e+18   jewelry.earring       1.0     102.27    NaN
# 5             1  1.806829e+18   jewelry.earring       0.0     150.55    NaN
# 6             1  1.806829e+18   jewelry.earring       0.0      83.42    NaN
# 7             1  1.806829e+18   jewelry.pendant       2.0      60.27      f
# 8             1  1.806829e+18   jewelry.earring       1.0     217.40    NaN
# 9             1  1.806829e+18      jewelry.ring       1.0     180.71    NaN
#
#   main_color main_metal  main_gem
# 0     yellow       gold       NaN
# 1      white       gold  sapphire
# ...

# %%
df.nunique()
# Out:
# Order_date        74504
# Order_ID          74759
# product_ID         9613
# SKU_quantity          1
# category_ID          25
# category_alias      218
# brand_ID           2537
# Price_USD          3166
# user_ID           31079
# gender                2
# main_color            5
# main_metal            3
# main_gem             30
# dtype: int64

# %%
#missing values
data_with_drop_column.isna().sum()
# Out:
# SKU_quantity          0
# category_ID        5352
# category_alias     9933
# brand_ID           4785
# Price_USD          5352
# gender            48167
# main_color         7660
# main_metal         5462
# main_gem          34058
# dtype: int64

# %%
#clean various columns
checked_columns = ["category_ID", "category_alias", "brand_ID", "gender", "main_color", "main_metal","main_gem"]

for col in checked_columns:
    print(f"\nTop values for {col} ")
    print(data_with_drop_column[col].value_counts(dropna=False).head(20))
# Out:
# Top values for category_ID
# category_ID
# 1.806829e+18    29000
# 1.806829e+18    28286
# 1.806829e+18    13052
# 1.806829e+18     9568
# 1.806829e+18     6185
# NaN              5352
# 1.806829e+18     2356
# 1.806829e+18     1288
# 1.806829e+18      321
# 1.806829e+18      170
# 1.806829e+18      130
# 1.313678e+18       41
# 1.313678e+18       37
# 1.313678e+18       27
# 1.806829e+18       22
# 1.313678e+18       14
# 1.806829e+18       12
# 1.313678e+18        9
# 1.313678e+18        9
# 1.313678e+18        9
# Name: count, dtype: int64
#
# Top values for category_alias
# category_alias
# jewelry.earring       29051
# jewelry.ring          28300
# jewelry.pendant       13088
# NaN                    9933
# jewelry.bracelet       6188
# 0.00                   4392
# jewelry.necklace       2361
# jewelry.brooch         1288
# jewelry.souvenir        170
# electronics.clocks      167
# 40.82                    54
# 231.51                   45
# 261.64                   43
# ...
